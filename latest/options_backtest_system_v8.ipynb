# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
sys.path.append(os.getcwd())

# Install accelerator if missing (Uncomment to install)
# !pip install numba 

from backtest_ui import launch
launch()
# Out:
# ✅ CPU Acceleration Enabled (Numba)
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ...
